# %% [markdown]
# # Imports

# %%
from google.colab import files
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %% [markdown]
# # Upload

# %%
arquivos = files.upload()

# %% [markdown]
# # Leitura e exibição da imagem

# %%
img = cv2.imread('pou_fudido.jpg')
cv2_imshow(img)

# %%
img

# %% [markdown]
# # Visualização das matrizes da imagem

# %%
img.shape

# %%
print(img)

# %% [markdown]
# # Edições manuais

# %%
cv2_imshow(img*0)
cv2_imshow(img/0)

# %%
for i in range(256):
  cv2_imshow(img*i)
  cv2_imshow(img/i)
  cv2_imshow(img+i)
  cv2_imshow(img-i)
  print(i)

# %%
cv2_imshow(img*255)
cv2_imshow(img/255)

# %% [markdown]
# # Visualização individual de cada canal de cor

# %%
B, G, R = cv2.split(img)

# %%
B

# %%
G

# %%
R

# %%
cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
